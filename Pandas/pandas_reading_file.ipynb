# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_table("chiporders.tsv")  #read table a common function to read a table
df.head(10)  # by default this function return the top 5 rows currently it is top 10 rows
df.tail()    # by default this function return the bottom 5 rows
df.sample(5)  # return any random number of rows
# Out:
#       order_id  quantity            item_name  \
# 54          25         1           Steak Bowl
# 56          26         1  Barbacoa Soft Tacos
# 2294       921         1        Bottled Water
# 3853      1544         1         Chicken Bowl
# 1532       624         1     Barbacoa Burrito
#
#                                      choice_description item_price
# 54    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.99
# 56    [Fresh Tomato Salsa, [Fajita Vegetables, Black...     $9.25
# 2294                                                NaN     $1.50
# 3853  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...     $8.75
# 1532  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...     $8.99

# %%
df=pd.read_table("fifa_data.csv", sep=",") # we can read csv file with read_table() as well but we have to mention the separater
#df=pd.read_csv("fifa_data.csv")
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
c=["Id","Age","Gender","Designation","Salary"]
df=pd.read_table("psd.user", sep="|",header=None, names=c)  # (header = None) if don't have any header in our file, then we mention header = None as it will not consider the 1 row of data as header.
df.head(3)                                                  # names atttribute : using this attribute we can rename the column header
# Out:
#    Id  Age Gender Designation Salary
# 0   1   24      M  technician  85711
# 1   2   53      F       other  94043
# 2   3   23      M      writer  32067

# %%
df=pd.read_json("simple.json") # (lines=false) by default attribute cause we had multiple dictionaries that were packed within list so no need to read multiple lines
df
# Out:
#        name  age grade
# 0     Andew   12     A
# 1    Bhuvan   18     B
# 2   Clinton   11     A
# 3     Drake   12     C
# 4     Eisha   13     B
# 5    Farhan   22     C
# 6    Garima   11     A
# 7  Himanshu   19     A
# 8    Ishaan   10     D
# 9     Jason    9     B

# %%
df=pd.read_json("simple_records.json", lines=True) # lines attribute cause we had multiple dictionaries (many json object) that were not packed
df
# Out:
#        name  age grade
# 0     Andew   12     A
# 1    Bhuvan   18     B
# 2   Clinton   11     A
# 3     Drake   12     C
# 4     Eisha   13     B
# 5    Farhan   22     C
# 6    Garima   11     A
# 7  Himanshu   19     A
# 8    Ishaan   10     D
# 9     Jason    9     B

# %%
df=pd.read_csv("movies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.info()  
'''
return datatype, number of rows indexes, number of columns, description of columns i.e, column index, column name,
Not-Null count and datatype of column, number of columns with dtype and memoru usage
'''
# It gives a consise summary of a dataFrame including index information, data type of columns non-null values and memory usage
# 2   content_rating  976 non-null    object -------976 not null rows means 3 null rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB
# '\nreturn datatype, number of rows indexes, number of columns, description of columns i.e, column index, column name,\nNot-Null count and datatype of column, number of columns with dtype and memoru usage\n'

# %%
df.isnull().sum()  # isnull() return true false for each cell---- method chaining it with sum() to find the total count of true in each column
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
df.title  # accessing a particular column
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
df["title"]    # accessing a particular column by indexing -------- more preferable
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
df[["star_rating","genre","duration"]]  # accesseing multiple coulmns using double square bracket
# Out:
#      star_rating      genre  duration
# 0            9.3      Crime       142
# 1            9.2      Crime       175
# 2            9.1      Crime       200
# 3            9.0     Action       152
# 4            8.9      Crime       154
# ..           ...        ...       ...
# 974          7.4     Comedy       116
# 975          7.4  Adventure       118
# 976          7.4     Action       138
# 977          7.4     Horror       114
# 978          7.4      Crime       126
#
# [979 rows x 3 columns]

# %%
df["star_rating"].max()  #
# Out:
# 9.3

# %%
df["star_rating"].min()
# Out:
# 7.4

# %%
df["star_rating"].mean()
# Out:
# 7.889785495403474

# %%
df.describe()  # statstical calculation of numerical column
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000
